# %%
name = input("Enter your name:")
print(name)
len(name)
# Out:
# Manisha
# 7

# %%
name.lower()
# Out:
# 'manisha'

# %%
name.upper()
# Out:
# 'MANISHA'

# %%
part1 = "Learn Data Science"
part1.replace(" ","_")
# Out:
# 'Learn_Data_Science'

# %%
course_name = "Data Science"
course_name[::-1]
# Out:
# 'ecneicS ataD'

# %%
slogan = "  Learning Python is simple and Python is powerful  "
print(slogan)
slogan.strip()
# Out:
#   Learning Python is simple and Python is powerful
# 'Learning Python is simple and Python is powerful'

# %%
slogan1 = "Learning Python is simple and Python is powerful"
slogan1.startswith("L")
# Out:
# True

# %%
slogan1.index("Python")
# Out:
# 9

# %%
slogan1.count("P")
# Out:
# 2

# %%
slogan1.split()
# Out:
# ['Learning', 'Python', 'is', 'simple', 'and', 'Python', 'is', 'powerful']

# %%
'madam' == 'madam'
# Out:
# True

# %%
word = input("check if word is palindrom")
print(word)

word == word[::-1]
# Out:
# mom
# True

# %%
sentence = "check if word is palindrom"
sentence.split()
word=sentence.split()
print(word)
len(word)
# Out:
# ['check', 'if', 'word', 'is', 'palindrom']
# 5

# %%
list_words = ['check', 'if', 'word', 'is', 'palindrom']
" ".join(list_words)
# Out:
# 'check if word is palindrom'

# %%
sentence = "Learn Data Engineering"
sentence.replace("Data Engineering", "Data science")
# Out:
# 'Learn Data science'
